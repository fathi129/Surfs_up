# %%
import pandas as pd

# %%
l_stop_df=pd.read_csv("Database/CTA_list_of_L_stops.csv")
l_stop_df
# Out:
#      STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0      30162            W         18th (54th/Cermak-bound)
# 1      30161            E                18th (Loop-bound)
# 2      30022            N         35th/Archer (Loop-bound)
# 3      30023            S       35th/Archer (Midway-bound)
# 4      30214            S  35-Bronzeville-IIT (63rd-bound)
# ..       ...          ...                              ...
# 295    30105            N            Wilson (Howard-bound)
# 296    30239            N           Addison (O'Hare-bound)
# 297    30106            S              Wilson (95th-bound)
# 298    30383            N   Washington/Wabash (Outer Loop)
# 299    30385            S              Wilson (Loop-bound)
#
#              STATION_NAME                           STATION_DESCRIPTIVE_NAME  \
# 0                    18th                                   18th (Pink Line)
# 1                    18th                                   18th (Pink Line)
# ...

# %%
ridership_df=pd.read_csv("Database/CTA_ridership_daily_totals.csv")
ridership_df
# Out:
#         station_id             stationname        date daytype  rides
# 0            40050                   Davis    1/1/2016       U   1415
# 1            41200                  Argyle    1/1/2016       U   1741
# 2            40970      Cicero-Forest Park    1/1/2016       U    722
# 3            40490         Grand/Milwaukee    1/1/2016       U   1700
# 4            41130          Halsted-Orange    1/1/2016       U    764
# ...            ...                     ...         ...     ...    ...
# 258104       41660              Lake/State  11/30/2020       W   2945
# 258105       41670            Conservatory  11/30/2020       W    412
# 258106       41680           Oakton-Skokie  11/30/2020       W    191
# 258107       41690  Cermak-McCormick Place  11/30/2020       W    373
# 258108       41700       Washington/Wabash  11/30/2020       W   2041
#
# [258109 rows x 5 columns]

# %%
l_stop_df['MAP_ID'].nunique()
# Out:
# 143

# %%
station_bools = l_stop_df[['MAP_ID','ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].groupby('MAP_ID').any()
l_stations_df = l_stops_df[['MAP_ID','STATION_NAME','STATION_DESCRIPTIVE_NAME','Location']] \
    .merge(station_bools, how='left', left_on='MAP_ID', right_index=True).drop_duplicates()
l_stations_df
# Out:
#      MAP_ID            STATION_NAME  \
# 0     40830                    18th
# 2     40120             35th/Archer
# 4     41120    35th-Bronzeville-IIT
# 6     41270                    43rd
# 8     40130                    51st
# ..      ...                     ...
# 286   40220                 Western
# 289   41690  Cermak-McCormick Place
# 291   40540                  Wilson
# 292   41700       Washington/Wabash
# 293   41240                 Addison
#
#                               STATION_DESCRIPTIVE_NAME  \
# 0                                     18th (Pink Line)
# 2                            35th/Archer (Orange Line)
# 4                    35th-Bronzeville-IIT (Green Line)
# 6                                    43rd (Green Line)
# 8                                    51st (Green Line)
# ..                                                 ...
# 286           Western (Blue Line - Forest Park Branch)
# 289                Cermak-McCormick Place (Green Line)
# ...

# %%
l_stations_df[['latitude','longitude']] = l_stations_df['Location'].str.replace('\(|\)','', regex=True).str.split(',',expand=True).apply(pd.to_numeric)
l_stations_df
# Out:
#      MAP_ID            STATION_NAME  \
# 0     40830                    18th
# 2     40120             35th/Archer
# 4     41120    35th-Bronzeville-IIT
# 6     41270                    43rd
# 8     40130                    51st
# ..      ...                     ...
# 286   40220                 Western
# 289   41690  Cermak-McCormick Place
# 291   40540                  Wilson
# 292   41700       Washington/Wabash
# 293   41240                 Addison
#
#                               STATION_DESCRIPTIVE_NAME  \
# 0                                     18th (Pink Line)
# 2                            35th/Archer (Orange Line)
# 4                    35th-Bronzeville-IIT (Green Line)
# 6                                    43rd (Green Line)
# 8                                    51st (Green Line)
# ..                                                 ...
# 286           Western (Blue Line - Forest Park Branch)
# 289                Cermak-McCormick Place (Green Line)
# ...

# %%
df = pd.merge(ridership_df, l_stations_df, how='left', left_on='station_id', right_on='MAP_ID')
df
# Out:
#         station_id             stationname        date daytype  rides  \
# 0            40050                   Davis    1/1/2016       U   1415
# 1            41200                  Argyle    1/1/2016       U   1741
# 2            40970      Cicero-Forest Park    1/1/2016       U    722
# 3            40490         Grand/Milwaukee    1/1/2016       U   1700
# 4            41130          Halsted-Orange    1/1/2016       U    764
# ...            ...                     ...         ...     ...    ...
# 258104       41660              Lake/State  11/30/2020       W   2945
# 258105       41670            Conservatory  11/30/2020       W    412
# 258106       41680           Oakton-Skokie  11/30/2020       W    191
# 258107       41690  Cermak-McCormick Place  11/30/2020       W    373
# 258108       41700       Washington/Wabash  11/30/2020       W   2041
#
#          MAP_ID            STATION_NAME  \
# 0       40050.0                   Davis
# 1       41200.0                  Argyle
# ...

# %%
df['south_side'] = df['latitude'] < 41.881

# %%
df.south_side
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True
#           ...
# 258104    False
# 258105    False
# 258106    False
# 258107     True
# 258108    False
# Name: south_side, Length: 258109, dtype: bool

# %%
df
# Out:
#         station_id             stationname        date daytype  rides  \
# 0            40050                   Davis    1/1/2016       U   1415
# 1            41200                  Argyle    1/1/2016       U   1741
# 2            40970      Cicero-Forest Park    1/1/2016       U    722
# 3            40490         Grand/Milwaukee    1/1/2016       U   1700
# 4            41130          Halsted-Orange    1/1/2016       U    764
# ...            ...                     ...         ...     ...    ...
# 258104       41660              Lake/State  11/30/2020       W   2945
# 258105       41670            Conservatory  11/30/2020       W    412
# 258106       41680           Oakton-Skokie  11/30/2020       W    191
# 258107       41690  Cermak-McCormick Place  11/30/2020       W    373
# 258108       41700       Washington/Wabash  11/30/2020       W   2041
#
#          MAP_ID            STATION_NAME  \
# 0       40050.0                   Davis
# 1       41200.0                  Argyle
# ...

# %%
rides = df['rides'].groupby(df['south_side']).sum()
rides
# Out:
# south_side
# False    532419304
# True     275328019
# Name: rides, dtype: int64

# %%
engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/cta_db")
l_stations_df.to_sql(name='stations', con=engine, index=False)
ridership_df.to_sql(name='ridership', con=engine, index=False)
